# %%
import pandas as pd

# %%
excel_names = ['rankingdata/melon.xlsx', 'rankingdata/bugs.xlsx', 'rankingdata/genie.xlsx']

# %%
append_data = pd.DataFrame()
for name in excel_names:
  pd_data = pd.read_excel(name)
  append_data = pd.concat([append_data, pd_data])
  
append_data.tail()
# Out:
#       서비스    순위                                           타이틀  \
# 95  Genie   96위                                    널 미워하기로 했어
# 96  Genie   97위  Yes or No (Feat. 허윤진 of LE SSERAFIM & Crush)
# 97  Genie   98위                                Off The Record
# 98  Genie   99위                                      Dynamite
# 99  Genie  100위                                    그중에 그대를 만나
#
#                    가수
# 95                이예준
# 96  그루비룸 (GroovyRoom)
# 97          IVE (아이브)
# 98              방탄소년단
# 99                김호중

# %%
append_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   서비스     300 non-null    object
#  1   순위      300 non-null    object
#  2   타이틀     300 non-null    object
#  3   가수      300 non-null    object
# dtypes: object(4)
# memory usage: 11.7+ KB

# %%
append_data
# Out:
#       서비스    순위                                           타이틀  \
# 0   melon    1위                                 Love wins all
# 1   melon    2위                              첫 만남은 계획대로 되지 않아
# 2   melon    3위                                           밤양갱
# 3   melon    4위                                         To. X
# 4   melon    5위                                        비의 랩소디
# ..    ...   ...                                           ...
# 95  Genie   96위                                    널 미워하기로 했어
# 96  Genie   97위  Yes or No (Feat. 허윤진 of LE SSERAFIM & Crush)
# 97  Genie   98위                                Off The Record
# 98  Genie   99위                                      Dynamite
# 99  Genie  100위                                    그중에 그대를 만나
#
#                    가수
# 0                 아이유
# 1           TWS (투어스)
# 2           비비 (BIBI)
# 3        태연 (TAEYEON)
# 4                 임재현
# ..                ...
# 95                이예준
# 96  그루비룸 (GroovyRoom)
# ...

# %%
append_data.to_excel('rankingdata/total.xlsx', index=False)

# %%
temp_df = pd.read_excel('rankingdata/total.xlsx')

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   서비스     300 non-null    object
#  1   순위      300 non-null    object
#  2   타이틀     300 non-null    object
#  3   가수      300 non-null    object
# dtypes: object(4)
# memory usage: 9.5+ KB

# %%
temp_df
# Out:
#        서비스    순위                                           타이틀  \
# 0    melon    1위                                 Love wins all
# 1    melon    2위                              첫 만남은 계획대로 되지 않아
# 2    melon    3위                                           밤양갱
# 3    melon    4위                                         To. X
# 4    melon    5위                                        비의 랩소디
# ..     ...   ...                                           ...
# 295  Genie   96위                                    널 미워하기로 했어
# 296  Genie   97위  Yes or No (Feat. 허윤진 of LE SSERAFIM & Crush)
# 297  Genie   98위                                Off The Record
# 298  Genie   99위                                      Dynamite
# 299  Genie  100위                                    그중에 그대를 만나
#
#                     가수
# 0                  아이유
# 1            TWS (투어스)
# 2            비비 (BIBI)
# 3         태연 (TAEYEON)
# 4                  임재현
# ..                 ...
# 295                이예준
# ...

# %%
temp_df['순위'].str.replace('위', '') # 순위 카테고리에 있는 '위'라는 단어를 공백으로 대치
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 295     96
# 296     97
# 297     98
# 298     99
# 299    100
# Name: 순위, Length: 300, dtype: object

# %%
a = temp_df['순위'].str.replace('위', '').astype(int) # 데이터타입을 int로 바꿔라 
a
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 295     96
# 296     97
# 297     98
# 298     99
# 299    100
# Name: 순위, Length: 300, dtype: int64

# %%
temp_df['순위'] = temp_df['순위'].str.replace('위', '').astype(int)
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   서비스     300 non-null    object
#  1   순위      300 non-null    int64
#  2   타이틀     300 non-null    object
#  3   가수      300 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 9.5+ KB

# %%
temp_df.head()
# Out:
#      서비스  순위               타이틀            가수
# 0  melon   1     Love wins all           아이유
# 1  melon   2  첫 만남은 계획대로 되지 않아     TWS (투어스)
# 2  melon   3               밤양갱     비비 (BIBI)
# 3  melon   4             To. X  태연 (TAEYEON)
# 4  melon   5            비의 랩소디           임재현

# %%
temp_df['순위'].isin([1, 2])
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 295    False
# 296    False
# 297    False
# 298    False
# 299    False
# Name: 순위, Length: 300, dtype: bool

# %%
# 순위가 1,2인 놈들만 좀 보자
# temp_df에서 조건이 [] 인 놈
temp_df[temp_df['순위'].isin([1, 2])]
# Out:
#        서비스  순위               타이틀         가수
# 0    melon   1     Love wins all        아이유
# 1    melon   2  첫 만남은 계획대로 되지 않아  TWS (투어스)
# 100   Bugs   1               밤양갱   비비(BIBI)
# 101   Bugs   2  첫 만남은 계획대로 되지 않아  TWS (투어스)
# 200  Genie   1  첫 만남은 계획대로 되지 않아  TWS (투어스)
# 201  Genie   2     Love wins all   아이유 (IU)

# %%
# 순위를 벨류로 바꾸고 sort_values을 통해 1,2,3 ... 순서대로 변경함.
# ascending 은 오름차순 asc

a = temp_df.sort_values(by='순위', ascending=True)
a.head(50)
# Out:
#        서비스  순위                                          타이틀  \
# 0    melon   1                                Love wins all
# 200  Genie   1                             첫 만남은 계획대로 되지 않아
# 100   Bugs   1                                          밤양갱
# 1    melon   2                             첫 만남은 계획대로 되지 않아
# 201  Genie   2                                Love wins all
# 101   Bugs   2                             첫 만남은 계획대로 되지 않아
# 2    melon   3                                          밤양갱
# 202  Genie   3                                          밤양갱
# 102   Bugs   3                                         EASY
# 3    melon   4                                        To. X
# 203  Genie   4                                       비의 랩소디
# 103   Bugs   4                                Love wins all
# 204  Genie   5                                        To. X
# 104   Bugs   5  Yes or No (Feat. 허윤진 of LE SSERAFIM, Crush)
# 4    melon   5                                       비의 랩소디
# ...

# %%
# 가수별 곡의 수
temp_df['가수'].value_counts()
# Out:
# 가수
# 임영웅                   27
# IVE (아이브)             21
# NewJeans              20
# LE SSERAFIM (르세라핌)    16
# (여자)아이들               13
#                       ..
# 폴킴(Paul Kim)           1
# The Kid LAROI          1
# 소수빈                    1
# 부석순(SEVENTEEN)         1
# 이예준                    1
# Name: count, Length: 97, dtype: int64

# %%
# 순위가 1위인 가수를 서비스와 가수로 출력하자.
temp_df[temp_df['순위'] == 1][['서비스','가수']]
# Out:
#        서비스         가수
# 0    melon        아이유
# 100   Bugs   비비(BIBI)
# 200  Genie  TWS (투어스)

# %%
# 가수별 평균 순위 탑 10
a = temp_df.groupby('가수')['순위'].agg(['min', 'max', 'mean'])
a.sort_values(by='mean').head(10)
# Out:
#                          min  max       mean
# 가수
# 비비(BIBI)                   1    1   1.000000
# 아이유                        1    1   1.000000
# TWS (투어스)                  1    2   1.666667
# 아이유 (IU)                   2    2   2.000000
# 비비 (BIBI)                  3    3   3.000000
# 아이유(IU)                    4    4   4.000000
# 임재현                        4   13   7.333333
# 너드커넥션 (Nerd Connection)    9   13  11.000000
# 박재정                        7   24  14.000000
# NMIXX                     15   15  15.000000

# %%
temp_df
# Out:
#        서비스   순위                                           타이틀  \
# 0    melon    1                                 Love wins all
# 1    melon    2                              첫 만남은 계획대로 되지 않아
# 2    melon    3                                           밤양갱
# 3    melon    4                                         To. X
# 4    melon    5                                        비의 랩소디
# ..     ...  ...                                           ...
# 295  Genie   96                                    널 미워하기로 했어
# 296  Genie   97  Yes or No (Feat. 허윤진 of LE SSERAFIM & Crush)
# 297  Genie   98                                Off The Record
# 298  Genie   99                                      Dynamite
# 299  Genie  100                                    그중에 그대를 만나
#
#                     가수
# 0                  아이유
# 1            TWS (투어스)
# 2            비비 (BIBI)
# 3         태연 (TAEYEON)
# 4                  임재현
# ..                 ...
# 295                이예준
# 296  그루비룸 (GroovyRoom)
# ...

# %%
temp_df.head()
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   서비스     300 non-null    object
#  1   순위      300 non-null    int64
#  2   타이틀     300 non-null    object
#  3   가수      300 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 9.5+ KB

# %%
# 순위 51위부터는 50위 이상으로 순위의 값을 변경해보자
# 순위가 50이상인 가수를 = '50위 이상'으로
temp_df.loc[temp_df['순위'] > 50, '가수'] = '50위 이상'

# %%
temp_df
# Out:
#        서비스   순위                                           타이틀            가수
# 0    melon    1                                 Love wins all           아이유
# 1    melon    2                              첫 만남은 계획대로 되지 않아     TWS (투어스)
# 2    melon    3                                           밤양갱     비비 (BIBI)
# 3    melon    4                                         To. X  태연 (TAEYEON)
# 4    melon    5                                        비의 랩소디           임재현
# ..     ...  ...                                           ...           ...
# 295  Genie   96                                    널 미워하기로 했어        50위 이상
# 296  Genie   97  Yes or No (Feat. 허윤진 of LE SSERAFIM & Crush)        50위 이상
# 297  Genie   98                                Off The Record        50위 이상
# 298  Genie   99                                      Dynamite        50위 이상
# 299  Genie  100                                    그중에 그대를 만나        50위 이상
#
# [300 rows x 4 columns]

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   서비스     300 non-null    object
#  1   순위      300 non-null    int64
#  2   타이틀     300 non-null    object
#  3   가수      300 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 9.5+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

songs_by_artist = temp_df['가수'].value_counts().reset_index()
songs_by_artist.columns = ['가수', '노래수']
songs_by_artist = songs_by_artist[1:]
songs_by_artist

plt.figure(figsize=(18, 6))
plt.rcParams['font.family'] = 'Apple SD Gothic Neo' #Malgun Gothic
sns.barplot(x='가수', y='노래수', data=songs_by_artist, palette='Set1')
plt.title('가수별 노래수')
plt.xlabel('가수')
plt.ylabel('노래수')
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/wt/2y6lq78x2_z3fsgwvz2bnhm80000gn/T/ipykernel_24015/4181477975.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='가수', y='노래수', data=songs_by_artist, palette='Set1')

# %%
plt.figure(figsize=(18, 6))
# plt.rcParams['font.family'] = 'Apple SD Gothic Neo' #Malgun Gothic
sns.boxplot(x='가수', y='순위', data=temp_df, palette='Set1')
plt.title('가수별 순위')
plt.xlabel('가수')
plt.ylabel('순위')
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/wt/2y6lq78x2_z3fsgwvz2bnhm80000gn/T/ipykernel_24015/2990410772.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='가수', y='순위', data=temp_df, palette='Set1')

# %%
temp_df
# Out:
#        서비스   순위                                           타이틀            가수
# 0    melon    1                                 Love wins all           아이유
# 1    melon    2                              첫 만남은 계획대로 되지 않아     TWS (투어스)
# 2    melon    3                                           밤양갱     비비 (BIBI)
# 3    melon    4                                         To. X  태연 (TAEYEON)
# 4    melon    5                                        비의 랩소디           임재현
# ..     ...  ...                                           ...           ...
# 295  Genie   96                                    널 미워하기로 했어        50위 이상
# 296  Genie   97  Yes or No (Feat. 허윤진 of LE SSERAFIM & Crush)        50위 이상
# 297  Genie   98                                Off The Record        50위 이상
# 298  Genie   99                                      Dynamite        50위 이상
# 299  Genie  100                                    그중에 그대를 만나        50위 이상
#
# [300 rows x 4 columns]

# %%
result = temp_df.groupby('가수')['순위'].mean().sort_values()
result[:5]
# Out:
# 가수
# 아이유          1.000000
# 비비(BIBI)     1.000000
# TWS (투어스)    1.666667
# 아이유 (IU)     2.000000
# 비비 (BIBI)    3.000000
# Name: 순위, dtype: float64

# %%
plt.figure(figsize=(12,6))
result.plot(kind='bar')
plt.show()

# %%
a = temp_df['가수'].value_counts().reset_index()
a.columns = ['가수', '빈도수']
a
# Out:
#                          가수  빈도수
# 0                    50위 이상  150
# 1                       임영웅   25
# 2                  NewJeans   12
# 3                 IVE (아이브)   11
# 4                   (여자)아이들   10
# 5        LE SSERAFIM (르세라핌)    8
# 6               DAY6 (데이식스)    6
# 7                     RIIZE    6
# 8                        정국    5
# 9                 AKMU (악뮤)    5
# 10             태연 (TAEYEON)    5
# 11                    aespa    4
# 12                      박재정    3
# 13              VIVIZ (비비지)    3
# 14              제니 (JENNIE)    3
# 15                      성시경    3
# 16                TWS (투어스)    3
# 17                      이무진    3
# 18                       범진    3
# 19                      임재현    3
# 20                 AKMU(악뮤)    2
# 21               우디 (Woody)    2
# 22  너드커넥션 (Nerd Connection)    2
# 23                비비 (BIBI)    2
# 24           윤하(Younha/ユンナ)    1
# 25                      최유리    1
# 26                Lauv(라우브)    1
# ...

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=a[1:], x='가수', y='빈도수')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.swarmplot(x='가수', y='순위', hue='서비스', data=temp_df, palette='Set1')
plt.xticks(rotation=90)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# title, category, subscriber, view, video

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome()

# %%
url = 'https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page=1'
driver.get(url)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
channel_list = soup.select('form > table > tbody > tr')
len(channel_list)
# Out:
# 100

# %%
channel = channel_list[0]
channel
# Out:
# <tr class="aos-init aos-animate" data-aos="fade-up" data-aos-duration="800">
# <td class="rank">
#                         1                    </td>
# <td class="td_img">
# <div class="info_img"><a href="https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&amp;wr_id=3203&amp;page=1"><img class="lazyload" data-src="https://yt3.ggpht.com/EMHEc8vNqHUC-eBFl_RrLcla7_NH6hEohpi0RrMABe6cOcmCabmnxcqfVFmONWTQg5LtbpNkQg=s88-c-k-c0x00ffffff-no-nd-rj" height="88" src="https://yt3.ggpht.com/EMHEc8vNqHUC-eBFl_RrLcla7_NH6hEohpi0RrMABe6cOcmCabmnxcqfVFmONWTQg5LtbpNkQg=s88-c-k-c0x00ffffff-no-nd-rj" width="88"/></a></div>
# <p class="info_rank">1</p>
# </td>
# <td class="subject">
# <h1>
# <p <a="" class="category" href="https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&amp;sca=%EC%9D%8C%EC%95%85%2F%EB%8C%84%EC%8A%A4%2F%EA%B0%80%EC%88%98">[음악/댄스/가수]
#
#                                 </p>
# ...

# %%
category = channel.select('p.category')[0].text
category = category.split('\n')[0]
category
# Out:
# '[음악/댄스/가수]'

# %%
title = channel.select('h1 > a')[0].text.strip()
title
# Out:
# 'BLACKPINK'

# %%
subscriber = channel.select('.subscriber_cnt')[0].text
subscriber
# Out:
# '9300만'

# %%
view = channel.select('.view_cnt')[0].text
view
# Out:
# '349억4750만'

# %%
video = channel.select('.video_cnt')[0].text
video
# Out:
# '592개'

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time


results = []
driver = webdriver.Chrome()
for i in range(1, 11):
  url = f'https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page={i}'
  driver.get(url)
  soup = BeautifulSoup(driver.page_source, 'html.parser')
  time.sleep(2)
  
  channel_list = soup.select('form > table > tbody > tr')
  for channel in channel_list:
    rank = channel.select('.rank')[0].text.strip()
    category = channel.select('p.category')[0].text
    category = category.split('\n')[0]
    title = channel.select('h1 > a')[0].text.strip()
    subscriber = channel.select('.subscriber_cnt')[0].text
    view = channel.select('.view_cnt')[0].text
    video = channel.select('.video_cnt')[0].text
    results.append([rank, category, title, subscriber, view, video])

# %%
print(results[:10])
print(len(results))
# Out:
# [['1', '[음악/댄스/가수]', 'BLACKPINK', '9300만', '349억4750만', '592개'], ['2', '[음악/댄스/가수]', 'BANGTANTV', '7750만', '222억8550만', '2,446개'], ['3', '[음악/댄스/가수]', 'HYBE LABELS', '7400만', '323억7728만', '1,628개'], ['4', '[미분류]', 'DaFuq!?Boom!', '3910만', '151억6719만', '282개'], ['5', '[BJ/인물/연예인]', '김프로KIMPRO', '3260만', '331억0174만', '2,667개'], ['7', '[미분류]', 'Mark Rober', '3230만', '48억9091만', '140개'], ['6', '[음악/댄스/가수]', 'SMTOWN', '3230만', '288억0952만', '4,307개'], ['8', '[음악/댄스/가수]', 'JYP Entertainment', '2870만', '218억1246만', '2,026개'], ['9', '[키즈/어린이]', 'Boram Tube Vlog [보람튜브 브이로그]', '2650만', '110억5288만', '223개'], ['11', '[해외]', 'Alan Becker', '2630만', '64억6998만', '190개']]
# 1000

# %%
import pandas as pd
df = pd.DataFrame(results, columns=['rank','category', 'title', 'subscriber', 'view', 'video'])
df.head(50)
# df.info()
# Out:
#    rank     category                              title subscriber       view  \
# 0     1   [음악/댄스/가수]                          BLACKPINK      9300만  349억4750만
# 1     2   [음악/댄스/가수]                          BANGTANTV      7750만  222억8550만
# 2     3   [음악/댄스/가수]                        HYBE LABELS      7400만  323억7728만
# 3     4        [미분류]                       DaFuq!?Boom!      3910만  151억6719만
# 4     5  [BJ/인물/연예인]                          김프로KIMPRO      3260만  331억0174만
# 5     7        [미분류]                         Mark Rober      3230만   48억9091만
# 6     6   [음악/댄스/가수]                             SMTOWN      3230만  288억0952만
# 7     8   [음악/댄스/가수]                  JYP Entertainment      2870만  218억1246만
# 8     9     [키즈/어린이]        Boram Tube Vlog [보람튜브 브이로그]      2650만  110억5288만
# 9    11         [해외]                        Alan Becker      2630만   64억6998만
# 10   10   [음악/댄스/가수]              1MILLION Dance Studio      2630만   81억3709만
# ...

# %%
df['rank'] = df['rank'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        1000 non-null   int64
#  1   category    1000 non-null   object
#  2   title       1000 non-null   object
#  3   subscriber  1000 non-null   object
#  4   view        1000 non-null   object
#  5   video       1000 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB

# %%
df_sort = df.sort_values(by='rank')
df_sort.head(50)
# Out:
#     rank     category                              title subscriber  \
# 0      1   [음악/댄스/가수]                          BLACKPINK      9300만
# 1      2   [음악/댄스/가수]                          BANGTANTV      7750만
# 2      3   [음악/댄스/가수]                        HYBE LABELS      7400만
# 3      4        [미분류]                       DaFuq!?Boom!      3910만
# 4      5  [BJ/인물/연예인]                          김프로KIMPRO      3260만
# 6      6   [음악/댄스/가수]                             SMTOWN      3230만
# 5      7        [미분류]                         Mark Rober      3230만
# 7      8   [음악/댄스/가수]                  JYP Entertainment      2870만
# 8      9     [키즈/어린이]        Boram Tube Vlog [보람튜브 브이로그]      2650만
# 10    10   [음악/댄스/가수]              1MILLION Dance Studio      2630만
# 9     11         [해외]                        Alan Becker      2630만
# 11    12   [음악/댄스/가수]                       1theK (원더케이)      2470만
# 12    13   [음악/댄스/가수]                         Mnet K-POP      2080만
# ...

# %%
df_sort.to_excel('../data/youtube_rank.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 df_sort.to_excel('../data/youtube_rank.xlsx', index=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
df = pd.read_excel('../data/youtube_rank.xlsx')
df.head()
# Out:
#    rank     category         title subscriber       view   video
# 0     1   [음악/댄스/가수]     BLACKPINK      9300만  349억4750만    592개
# 1     2   [음악/댄스/가수]     BANGTANTV      7750만  222억8550만  2,446개
# 2     3   [음악/댄스/가수]   HYBE LABELS      7400만  323억5336만  1,626개
# 3     4        [미분류]  DaFuq!?Boom!      3910만  151억5370만    282개
# 4     5  [BJ/인물/연예인]     김프로KIMPRO      3260만  330억6429만  2,662개

# %%
df['new_subscriber'] = df['subscriber'].str.replace('만', '0000').astype(int)

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   rank            1000 non-null   int64
#  1   category        1000 non-null   object
#  2   title           1000 non-null   object
#  3   subscriber      1000 non-null   object
#  4   view            1000 non-null   object
#  5   video           1000 non-null   object
#  6   new_subscriber  1000 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 54.8+ KB
#    rank     category         title subscriber       view   video  \
# 0     1   [음악/댄스/가수]     BLACKPINK      9300만  349억4750만    592개
# 1     2   [음악/댄스/가수]     BANGTANTV      7750만  222억8550만  2,446개
# 2     3   [음악/댄스/가수]   HYBE LABELS      7400만  323억5336만  1,626개
# 3     4        [미분류]  DaFuq!?Boom!      3910만  151억5370만    282개
# 4     5  [BJ/인물/연예인]     김프로KIMPRO      3260만  330억6429만  2,662개
#
# ...

# %%
tmp_ = df.pivot_table(index='category', values='new_subscriber', aggfunc=['sum', 'count'])
tmp_.columns = ['구독자수합', '채널수']
tmp_.sort_values(by='구독자수합', ascending=False)
# Out:
#                  구독자수합  채널수
# category
# [음악/댄스/가수]   852890000  147
# [미분류]        443990000  207
# [키즈/어린이]     420440000  128
# [TV/방송]      275700000  113
# [음식/요리/레시피]  223870000   69
# [BJ/인물/연예인]  159930000   59
# [뉴스/정치/사회]   113460000   58
# [해외]          77900000   15
# [게임]          74010000   49
# [취미/라이프]      51050000   29
# [영화/만화/애니]    47010000   29
# [패션/미용]       33880000   21
# [애완/반려동물]     29380000   16
# [교육/강의]       28830000   18
# [회사/오피셜]      22680000    7
# [스포츠/운동]      18090000   10
# [국내/해외/여행]    12210000   10
# [IT/기술/컴퓨터]   10950000    7
# [주식/경제/부동산]    9220000    6
# [자동차]          2200000    2
